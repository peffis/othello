# %% [markdown]
# # Othello + TD(λ)
#
# Learning experiment: a tanh-output MLP trained by TD(λ) self-play on Othello. Game logic and learner live in the `othello` package; this notebook is just a driver.
#
# See `tests/` for unit tests (`pytest -q`).

# %%
# pip install numpy keras tensorflow matplotlib

# %%
from othello.board import Board, WHITE, BLACK
from othello.players import RandomPlayer, GreedyPlayer, NoisyGreedyPlayer, InteractivePlayer
from othello.game import play_game
from othello.td import TDPlayer, TDPlayerConv

# %%
# Self-training with learning-curve logging.
# Each epoch: play N_GAMES_PER_EPOCH self-play training games, then
# evaluate against a noisy greedy opponent over N_TESTS_PER_EPOCH games.
# Results are appended to experiments['TDPlayer'] for later plotting.

F_NAME = 'tdPlayer'

N_EPOCHS = 500
N_GAMES_PER_EPOCH = 50
N_TESTS_PER_EPOCH = 200
EVAL_OPPONENT_EPSILON = 0.1   # noise on the GreedyPlayer during eval

# Persist the experiments dict across re-runs of this cell so a
# re-run of training does not wipe any other experiment logs that
# may already be in the namespace.
try:
    experiments
except NameError:
    experiments = {}

whitePlayer = TDPlayer(WHITE)
# Uncomment to resume from a saved model instead of starting fresh:
# whitePlayer.load(F_NAME)
blackPlayer = TDPlayer(BLACK, model=whitePlayer.model)


def evaluate(player):
    """Play N_TESTS_PER_EPOCH games vs a noisy-greedy opponent.
    Temporarily forces player.epsilon = 0 so we measure the pure
    greedy TD policy (the opponent's epsilon provides the variance)."""
    saved_eps = player.epsilon
    player.epsilon = 0.0
    wins = losses = ties = 0
    try:
        for _ in range(N_TESTS_PER_EPOCH):
            w, b_, _ = play_game(
                NoisyGreedyPlayer(BLACK, epsilon=EVAL_OPPONENT_EPSILON),
                player,
                verbose=False, allowContemplation=False,
            )
            if w > b_:
                wins += 1
            elif b_ > w:
                losses += 1
            else:
                ties += 1
    finally:
        player.epsilon = saved_eps
    return {
        'wins': wins, 'losses': losses, 'ties': ties,
        'win_pct': 100.0 * wins / N_TESTS_PER_EPOCH,
    }


log = []

# Pre-training baseline at games_played = 0.
print(f'pre-training baseline ({N_TESTS_PER_EPOCH} games)...', flush=True)
result = evaluate(whitePlayer)
log.append({'epoch': 0, 'games_played': 0, **result})
print('  win_pct={win_pct:.2f}%  (W {wins} / L {losses} / T {ties})'.format(**result))

for epoch in range(1, N_EPOCHS + 1):
    print(f'epoch {epoch}/{N_EPOCHS} \u2014 training... ', end='', flush=True)
    for _ in range(N_GAMES_PER_EPOCH):
        play_game(blackPlayer, whitePlayer, verbose=False)
    print('evaluating... ', end='', flush=True)
    result = evaluate(whitePlayer)
    log.append({
        'epoch': epoch,
        'games_played': epoch * N_GAMES_PER_EPOCH,
        **result,
    })
    print('win_pct={win_pct:.2f}%  (W {wins} / L {losses} / T {ties})'.format(**result))
    whitePlayer.save(F_NAME)

experiments['TDPlayer'] = log
print(f'\ndone \u2014 {len(log)} points logged under experiments["TDPlayer"]')

# %%
# Self-training TDPlayerConv with learning-curve logging. Same
# cadence as the TDPlayer cell above, distinct F_NAME so the saved
# weights don't collide, results logged under experiments['TDPlayerConv']
# so the plot cell below picks them up automatically.

F_NAME = 'tdPlayerConv'

N_EPOCHS = 500
N_GAMES_PER_EPOCH = 50
N_TESTS_PER_EPOCH = 200
EVAL_OPPONENT_EPSILON = 0.1

try:
    experiments
except NameError:
    experiments = {}

whitePlayer = TDPlayerConv(WHITE)
# Uncomment to resume from a saved model instead of starting fresh:
# whitePlayer.load(F_NAME)
blackPlayer = TDPlayerConv(BLACK, model=whitePlayer.model)


def evaluate(player):
    """Play N_TESTS_PER_EPOCH games vs a noisy-greedy opponent.
    Temporarily forces player.epsilon = 0 so we measure the pure
    greedy TD policy (the opponent's epsilon provides the variance)."""
    saved_eps = player.epsilon
    player.epsilon = 0.0
    wins = losses = ties = 0
    try:
        for _ in range(N_TESTS_PER_EPOCH):
            w, b_, _ = play_game(
                NoisyGreedyPlayer(BLACK, epsilon=EVAL_OPPONENT_EPSILON),
                player,
                verbose=False, allowContemplation=False,
            )
            if w > b_:
                wins += 1
            elif b_ > w:
                losses += 1
            else:
                ties += 1
    finally:
        player.epsilon = saved_eps
    return {
        'wins': wins, 'losses': losses, 'ties': ties,
        'win_pct': 100.0 * wins / N_TESTS_PER_EPOCH,
    }


log = []

# Pre-training baseline at games_played = 0.
print(f'pre-training baseline ({N_TESTS_PER_EPOCH} games)...', flush=True)
result = evaluate(whitePlayer)
log.append({'epoch': 0, 'games_played': 0, **result})
print('  win_pct={win_pct:.2f}%  (W {wins} / L {losses} / T {ties})'.format(**result))

for epoch in range(1, N_EPOCHS + 1):
    print(f'epoch {epoch}/{N_EPOCHS} \u2014 training... ', end='', flush=True)
    for _ in range(N_GAMES_PER_EPOCH):
        play_game(blackPlayer, whitePlayer, verbose=False)
    print('evaluating... ', end='', flush=True)
    result = evaluate(whitePlayer)
    log.append({
        'epoch': epoch,
        'games_played': epoch * N_GAMES_PER_EPOCH,
        **result,
    })
    print('win_pct={win_pct:.2f}%  (W {wins} / L {losses} / T {ties})'.format(**result))
    whitePlayer.save(F_NAME)

experiments['TDPlayerConv'] = log
print(f'\ndone \u2014 {len(log)} points logged under experiments["TDPlayerConv"]')

# %%
# Learning-curve plot. Re-runnable after any new experiment is added.
# Add more entries to the experiments dict (e.g. experiments['ConvNet'] = [...])
# and re-run this cell to compare.

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
for name, lg in experiments.items():
    xs = [e['games_played'] for e in lg]
    ys = [e['win_pct'] for e in lg]
    plt.plot(xs, ys, marker='.', label=name)
plt.xlabel('Training games played')
plt.ylabel('Win % vs NoisyGreedyPlayer (\u03b5=0.1)')
plt.title('Learning curve vs NoisyGreedyPlayer')
plt.legend()
plt.grid(True, alpha=0.3)
plt.ylim(0, 100)
plt.show()

# %%
# Human vs. trained model.
F_NAME = 'tdPlayer'

whitePlayer = TDPlayer(WHITE)
whitePlayer.load(F_NAME)
whitePlayer.epsilon = 0.0  # greedy during play

whites, blacks, coords = play_game(
    InteractivePlayer(BLACK), whitePlayer,
    verbose=True, allowContemplation=False,
)

if whites > blacks:
    print('WHITE WON!')
elif blacks > whites:
    print('BLACK WON!')
else:
    print('THERE WAS A TIE!')
print('({} whites vs {} blacks)'.format(whites, blacks))
