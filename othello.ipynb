# %% [markdown]
# # Othello + TD(λ)
#
# Learning experiment: a tanh-output MLP trained by TD(λ) self-play on Othello. Game logic and learner live in the `othello` package; this notebook is just a driver.
#
# See `tests/` for unit tests (`pytest -q`).

# %%
# pip install numpy keras tensorflow

# %%
from othello.board import Board, WHITE, BLACK
from othello.players import RandomPlayer, GreedyPlayer, InteractivePlayer
from othello.game import play_game
from othello.td import TDPlayer

# %%
# self training
F_NAME = 'tdPlayer'

whitePlayer = TDPlayer(WHITE)
# Uncomment the next line to resume from a saved model:
# whitePlayer.load(F_NAME)

# Share the network between black and white for self-play.
blackPlayer = TDPlayer(BLACK, model=whitePlayer.model)

N_EPOCHS = 200
N_GAMES_PER_EPOCH = 500
N_TESTS_PER_EPOCH = 100

for epoch in range(N_EPOCHS):
    print('training epoch {}'.format(epoch + 1))
    for g in range(N_GAMES_PER_EPOCH):
        if g % 5 == 0:
            print('.', end='')
        play_game(blackPlayer, whitePlayer, verbose=False)

    whiteWins = blackWins = ties = 0
    print('\ntesting after epoch {}'.format(epoch + 1))
    for t in range(N_TESTS_PER_EPOCH):
        if t % 5 == 0:
            print('.', end='')
        whites, blacks, _ = play_game(
            RandomPlayer(BLACK), whitePlayer,
            verbose=False, allowContemplation=False,
        )
        if whites > blacks:
            whiteWins += 1
        elif blacks > whites:
            blackWins += 1
        else:
            ties += 1

    print('\ntest results after epoch {}'.format(epoch + 1))
    print('white wins: {}, black wins: {}, ties: {} ({}%)'.format(
        whiteWins, blackWins, ties,
        round(100.0 * whiteWins / N_TESTS_PER_EPOCH, 2),
    ))
    whitePlayer.save(F_NAME)

# %%
# human vs. trained model
F_NAME = 'tdPlayer'

whitePlayer = TDPlayer(WHITE)
whitePlayer.load(F_NAME)
whitePlayer.epsilon = 0.0  # greedy during play

whites, blacks, coords = play_game(
    InteractivePlayer(BLACK), whitePlayer,
    verbose=True, allowContemplation=False,
)

if whites > blacks:
    print('WHITE WON!')
elif blacks > whites:
    print('BLACK WON!')
else:
    print('THERE WAS A TIE!')
print('({} whites vs {} blacks)'.format(whites, blacks))
